# %% [markdown]
# Formatting data to read in pytorch.
#
# Since the dataset is small, I will randomly split the data into train, test and validation during run time.

# %%
# imports
import random, os

# %%
os.chdir('CV_problem_sober_drunk_database/')

# %%
folders = [f for f in os.listdir('CV_problem_sober_drunk_database/') if os.path.isdir(f)]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-15b787009192> in <module>
# ----> 1 folders = [f for f in os.listdir('CV_problem_sober_drunk_database/') if os.path.isdir(f)]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'CV_problem_sober_drunk_database/'
